# %%
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role
from sagemaker.predictor import json_deserializer

import boto3, csv, io, json
import numpy as np
from scipy.sparse import lil_matrix

# %%
nbUsers=943
nbFoodItems=1682
nbFeatures=nbUsers+nbFoodItems

nbRatingsTrain=90570
nbRatingsTest=943*1682

# %%
foodItemsByUser={}
for userId in range(nbUsers):
    foodItemsByUser[str(userId)] = []
    
with open('food.base','r') as f:
    samples=csv.reader(f,delimiter='\t')
    for userId,foodItemId,rating in samples:
        foodItemsByUser[str(int(userId)-1)].append(int(foodItemId)-1)

# %%
def loadDataset(filename, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    Y = []
    line=0
    with open(filename,'r') as f:
        samples=csv.reader(f,delimiter='\t')
        for userId,foodItemId,rating in samples:
            X[line,int(userId)-1] = 1
            X[line,int(nbUsers)+int(foodItemId)-1] = 1
            if int(rating) >= 4:
                Y.append(1)
            else:
                Y.append(0)
            line=line+1
            
    Y=np.array(Y).astype('float32')
    return X,Y

# %%
X_train, Y_train = loadDataset('food.base', nbRatingsTrain, nbFeatures)
X_test, Y_test = loadDataset('food1.test',nbRatingsTest,nbFeatures)
print("train and test data loaded")
# Out:
# train and test data loaded

# %%
print(X_train.shape)
print(Y_train.shape)
assert X_train.shape == (nbRatingsTrain, nbFeatures)
assert Y_train.shape == (nbRatingsTrain, )
zero_labels = np.count_nonzero(Y_train)
print("Training labels: %d zeros, %d ones" % (zero_labels, nbRatingsTrain-zero_labels))

print(X_test.shape)
print(Y_test.shape)
assert X_test.shape  == (nbRatingsTest, nbFeatures)
assert Y_test.shape  == (nbRatingsTest, )
zero_labels = np.count_nonzero(Y_test)
print("Test labels: %d zeros, %d ones" % (zero_labels, nbRatingsTest-zero_labels))
# Out:
# (90570, 2625)
# (90570,)
# Training labels: 49906 zeros, 40664 ones
# (1586126, 2625)
# (1586126,)
# Test labels: 635777 zeros, 950349 ones

# %%
bucket = 'food-recommender'
prefix = 'sagemaker/fm-food'

train_key      = 'train.protobuf'
train_prefix   = '{}/{}'.format(prefix, 'train3')

test_key       = 'test.protobuf'
test_prefix    = '{}/{}'.format(prefix, 'test3')

output_prefix  = 's3://{}/{}/output'.format(bucket, prefix)

# %%
def writeDatasetToProtobuf(X, Y, bucket, prefix, key):
    buf = io.BytesIO()
    smac.write_spmatrix_to_sparse_tensor(buf, X, Y)
    buf.seek(0)
    obj = '{}/{}'.format(prefix, key)
    boto3.resource('s3').Bucket(bucket).Object(obj).upload_fileobj(buf)
    return 's3://{}/{}'.format(bucket,obj)
    
train_data = writeDatasetToProtobuf(X_train, Y_train, bucket, train_prefix, train_key)    
test_data  = writeDatasetToProtobuf(X_test, Y_test, bucket, test_prefix, test_key)    
  
print(train_data)
print(test_data)
print('Output: {}'.format(output_prefix))
# Out:
# s3://food-recommender/sagemaker/fm-food/train3/train.protobuf
# s3://food-recommender/sagemaker/fm-food/test3/test.protobuf
# Output: s3://food-recommender/sagemaker/fm-food/output

# %%
containers = {'us-west-2': '174872318107.dkr.ecr.us-west-2.amazonaws.com/factorization-machines:latest',
              'us-east-1': '382416733822.dkr.ecr.us-east-1.amazonaws.com/factorization-machines:latest',
              'us-east-2': '404615174143.dkr.ecr.us-east-2.amazonaws.com/factorization-machines:latest',
              'eu-west-1': '438346466558.dkr.ecr.eu-west-1.amazonaws.com/factorization-machines:latest',
              'ap-south-1':'991648021394.dkr.ecr.ap-south-1.amazonaws.com/factorization-machines:latest'
             }

# %%
fm = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
'arn:aws:iam::851078371316:role/FoodSageMakerRole', 
                                   train_instance_count=1, 
                                   train_instance_type='ml.c4.xlarge',
                                   output_path=output_prefix,
                                   sagemaker_session=sagemaker.Session())

fm.set_hyperparameters(feature_dim=nbFeatures,
                      predictor_type='binary_classifier',
                      mini_batch_size=1000,
                      num_factors=64,
                      epochs=100)

fm.fit({'train': train_data, 'test': test_data})
#print(fm)
# Out:
# INFO:sagemaker:Creating training-job with name: factorization-machines-2019-03-16-08-30-58-152
# 2019-03-16 08:30:58 Starting - Starting the training job...
# 2019-03-16 08:30:59 Starting - Launching requested ML instances......
# 2019-03-16 08:32:00 Starting - Preparing the instances for training......
# 2019-03-16 08:33:23 Downloading - Downloading input data..
# Docker entrypoint called with argument(s): train
# [03/16/2019 08:33:41 INFO 139869249693504] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [03/16/2019 08:33:41 INFO 139869249693504] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'100', u'feature_dim': u'2625', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier', u'num_factors': u'64'}
# [03/16/2019 08:33:41 INFO 139869249693504] Final configuration: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': u'100', u'feature_dim': u'2625', u'num_factors': u'64', u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'predictor_type': u'binary_classifier', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [03/16/2019 08:33:41 WARNING 139869249693504] Loggers have already been setup.
# Process 1 is a worker.
# [03/16/2019 08:33:41 INFO 139869249693504] Using default worker.
# [2019-03-16 08:33:41.120] [tensorio] [info] batch={"data_pipeline": "/opt/ml/input/data/train", "num_examples": 1000, "features": [{"name": "label_values", "shape": [1], "storage_type": "dense"}, {"name": "values", "shape":
"Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725230.984907}
#
# [03/16/2019 08:33:51 INFO 139869249693504] #progress_metric: host=algo-1, completed 16 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1457, "sum": 1457.0, "min": 1457}, "Total Records Seen": {"count": 1, "max": 1450120, "sum": 1450120.0, "min": 1450120}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1552725231.56232, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 15}, "StartTime": 1552725230.985274}
#
# [03/16/2019 08:33:51 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=156921.903528 records/second
# [2019-03-16 08:33:51.562] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 16, "duration": 575, "num_examples": 91}
# [03/16/2019 08:33:51 INFO 139869249693504] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_accuracy <score>=0.743
# [03/16/2019 08:33:51 INFO 139869249693504] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_cross_entropy <loss>=0.59048815918
# [03/16/2019 08:33:51 INFO 139869249693504] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_f_1.000 <score>=0.775545851528
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=16, train binary_classification_accuracy <score>=0.723351648352
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=16, train binary_classification_cross_entropy <loss>=0.586440392127
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=16, train binary_f_1.000 <score>=0.766788020269
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 603.8808822631836, "sum": 603.8808822631836, "min": 603.8808822631836}}, "EndTime": 1552725232.166513, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725231.562149}
#
# [03/16/2019 08:33:52 INFO 139869249693504] #progress_metric: host=algo-1, completed 17 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1548, "sum": 1548.0, "min": 1548}, "Total Records Seen": {"count": 1, "max": 1540690, "sum": 1540690.0, "min": 1540690}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1552725232.166703, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 16}, "StartTime": 1552725231.5626}
#
# [03/16/2019 08:33:52 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=149895.991395 records/second
# [2019-03-16 08:33:52.166] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 17, "duration": 602, "num_examples": 91}
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_accuracy <score>=0.745
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_cross_entropy <loss>=0.587571655273
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_f_1.000 <score>=0.776902887139
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=17, train binary_classification_accuracy <score>=0.724978021978
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=17, train binary_classification_cross_entropy <loss>=0.583492461152
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=17, train binary_f_1.000 <score>=0.767391930702
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 572.1960067749023, "sum": 572.1960067749023, "min": 572.1960067749023}}, "EndTime": 1552725232.739165, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725232.166577}
#
# [03/16/2019 08:33:52 INFO 139869249693504] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1639, "sum": 1639.0, "min": 1639}, "Total Records Seen": {"count": 1, "max": 1631260, "sum": 1631260.0, "min": 1631260}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1552725232.739426, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 17}, "StartTime": 1552725232.166934}
#
# [03/16/2019 08:33:52 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=158169.65361 records/second
# [2019-03-16 08:33:52.739] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 18, "duration": 571, "num_examples": 91}
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_accuracy <score>=0.745
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_cross_entropy <loss>=0.584838500977
# [03/16/2019 08:33:52 INFO 139869249693504] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_f_1.000 <score>=0.776902887139
# [03/16/2019 08:33:53 INFO 139869249693504] #quality_metric: host=algo-1, epoch=18, train binary_classification_accuracy <score>=0.725582417582
# [03/16/2019 08:33:53 INFO 139869249693504] #quality_metric: host=algo-1, epoch=18, train binary_classification_cross_entropy <loss>=0.580744111113
# ...
#
# [03/16/2019 08:34:38 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=145158.412252 records/second
# [2019-03-16 08:34:38.700] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 95, "duration": 622, "num_examples": 91}
# [03/16/2019 08:34:38 INFO 139869249693504] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_accuracy <score>=0.746
# [03/16/2019 08:34:38 INFO 139869249693504] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_cross_entropy <loss>=0.512345092773
# [03/16/2019 08:34:38 INFO 139869249693504] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_f_1.000 <score>=0.777192982456
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=95, train binary_classification_accuracy <score>=0.748318681319
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=95, train binary_classification_cross_entropy <loss>=0.516116627117
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=95, train binary_f_1.000 <score>=0.778232873396
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 563.3251667022705, "sum": 563.3251667022705, "min": 563.3251667022705}}, "EndTime": 1552725279.264406, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725278.700609}
#
# [03/16/2019 08:34:39 INFO 139869249693504] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8737, "sum": 8737.0, "min": 8737}, "Total Records Seen": {"count": 1, "max": 8695720, "sum": 8695720.0, "min": 8695720}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1552725279.264651, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 95}, "StartTime": 1552725278.701041}
#
# [03/16/2019 08:34:39 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=160662.630181 records/second
# [2019-03-16 08:34:39.264] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 96, "duration": 562, "num_examples": 91}
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_accuracy <score>=0.747
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_cross_entropy <loss>=0.511969482422
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_f_1.000 <score>=0.777875329236
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=96, train binary_classification_accuracy <score>=0.748384615385
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=96, train binary_classification_cross_entropy <loss>=0.515778861245
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=96, train binary_f_1.000 <score>=0.778282383244
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 567.1498775482178, "sum": 567.1498775482178, "min": 567.1498775482178}}, "EndTime": 1552725279.832112, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725279.264493}
#
# [03/16/2019 08:34:39 INFO 139869249693504] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8828, "sum": 8828.0, "min": 8828}, "Total Records Seen": {"count": 1, "max": 8786290, "sum": 8786290.0, "min": 8786290}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1552725279.83231, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 96}, "StartTime": 1552725279.264931}
#
# [03/16/2019 08:34:39 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=159594.681473 records/second
# [2019-03-16 08:34:39.832] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 97, "duration": 566, "num_examples": 91}
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_accuracy <score>=0.748
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_cross_entropy <loss>=0.511598510742
# [03/16/2019 08:34:39 INFO 139869249693504] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_f_1.000 <score>=0.778947368421
# [03/16/2019 08:34:40 INFO 139869249693504] #quality_metric: host=algo-1, epoch=97, train binary_classification_accuracy <score>=0.748571428571
# [03/16/2019 08:34:40 INFO 139869249693504] #quality_metric: host=algo-1, epoch=97, train binary_classification_cross_entropy <loss>=0.515443735982
# [03/16/2019 08:34:40 INFO 139869249693504] #quality_metric: host=algo-1, epoch=97, train binary_f_1.000 <score>=0.77844056242
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 572.4430084228516, "sum": 572.4430084228516, "min": 572.4430084228516}}, "EndTime": 1552725280.405009, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725279.832185}
#
# [03/16/2019 08:34:40 INFO 139869249693504] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8919, "sum": 8919.0, "min": 8919}, "Total Records Seen": {"count": 1, "max": 8876860, "sum": 8876860.0, "min": 8876860}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1552725280.405239, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 97}, "StartTime": 1552725279.832532}
#
# [03/16/2019 08:34:40 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=158109.746423 records/second
# [2019-03-16 08:34:40.405] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 98, "duration": 571, "num_examples": 91}
# [03/16/2019 08:34:40 INFO 139869249693504] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_accuracy <score>=0.748
# [03/16/2019 08:34:40 INFO 139869249693504] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_cross_entropy <loss>=0.511231933594
# [03/16/2019 08:34:40 INFO 139869249693504] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_f_1.000 <score>=0.778947368421
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=98, train binary_classification_accuracy <score>=0.748593406593
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=98, train binary_classification_cross_entropy <loss>=0.515111105112
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=98, train binary_f_1.000 <score>=0.778494248867
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 601.1688709259033, "sum": 601.1688709259033, "min": 601.1688709259033}}, "EndTime": 1552725281.006717, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725280.405086}
#
# [03/16/2019 08:34:41 INFO 139869249693504] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 9010, "sum": 9010.0, "min": 9010}, "Total Records Seen": {"count": 1, "max": 8967430, "sum": 8967430.0, "min": 8967430}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1552725281.00699, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 98}, "StartTime": 1552725280.405516}
#
# [03/16/2019 08:34:41 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=150549.747602 records/second
# [2019-03-16 08:34:41.007] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 99, "duration": 600, "num_examples": 91}
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_accuracy <score>=0.749
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_cross_entropy <loss>=0.510869628906
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_f_1.000 <score>=0.779631255487
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=99, train binary_classification_accuracy <score>=0.748824175824
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=99, train binary_classification_cross_entropy <loss>=0.514780814705
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, epoch=99, train binary_f_1.000 <score>=0.778699714383
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.748824175824
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.514780814705
# [03/16/2019 08:34:41 INFO 139869249693504] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.778699714383
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 610.785961151123, "sum": 610.785961151123, "min": 610.785961151123}}, "EndTime": 1552725281.618125, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725281.006791}
#
# [03/16/2019 08:34:41 INFO 139869249693504] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 9101, "sum": 9101.0, "min": 9101}, "Total Records Seen": {"count": 1, "max": 9058000, "sum": 9058000.0, "min": 9058000}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 101, "sum": 101.0, "min": 101}}, "EndTime": 1552725281.618317, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 99}, "StartTime": 1552725281.007312}
#
# [03/16/2019 08:34:41 INFO 139869249693504] #throughput_metric: host=algo-1, train throughput=148204.05401 records/second
# [03/16/2019 08:34:41 WARNING 139869249693504] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/16/2019 08:34:41 INFO 139869249693504] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 2.1331310272216797, "sum": 2.1331310272216797, "min": 2.1331310272216797}}, "EndTime": 1552725281.620715, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725281.618189}
#
# [03/16/2019 08:34:41 INFO 139869249693504] Saved checkpoint to "/tmp/tmp_Jh1Bm/state-0001.params"
# [2019-03-16 08:34:41.627] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "epoch": 0, "duration": 60504, "num_examples": 1}
#
# 2019-03-16 08:34:57 Uploading - Uploading generated training model
# 2019-03-16 08:34:57 Completed - Training job completed
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1587, "sum": 1587.0, "min": 1587}, "Number of Batches Since Last Reset": {"count": 1, "max": 1587, "sum": 1587.0, "min": 1587}, "Number of Records Since Last Reset": {"count": 1, "max": 1586126, "sum": 1586126.0, "min": 1586126}, "Total Batches Seen": {"count": 1, "max": 1587, "sum": 1587.0, "min": 1587}, "Total Records Seen": {"count": 1, "max": 1586126, "sum": 1586126.0, "min": 1586126}, "Max Records Seen Between Resets": {"count": 1, "max": 1586126, "sum": 1586126.0, "min": 1586126}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1552725287.24446, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725281.627206}
#
# [03/16/2019 08:34:47 INFO 139869249693504] #test_score (algo-1) : ('binary_classification_accuracy', 0.53612701639087945)
# [03/16/2019 08:34:47 INFO 139869249693504] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.75275987605133776)
# [03/16/2019 08:34:47 INFO 139869249693504] #test_score (algo-1) : ('binary_f_1.000', 0.3542551818985272)
# [03/16/2019 08:34:47 INFO 139869249693504] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.536127016391
# [03/16/2019 08:34:47 INFO 139869249693504] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.752759876051
# [03/16/2019 08:34:47 INFO 139869249693504] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.354255181899
# [2019-03-16 08:34:47.245] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "epoch": 1, "duration": 5617, "num_examples": 1587}
# [2019-03-16 08:34:47.245] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/test", "duration": 66121, "num_epochs": 2, "num_examples": 1588}
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 66173.53796958923, "sum": 66173.53796958923, "min": 66173.53796958923}, "setuptime": {"count": 1, "max": 40.760040283203125, "sum": 40.760040283203125, "min": 40.760040283203125}}, "EndTime": 1552725287.245473, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1552725281.620771}
#
# [2019-03-16 08:34:47.262] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "epoch": 100, "duration": 6254, "num_examples": 91}
# [2019-03-16 08:34:47.262] [tensorio] [info] data_pipeline_stats={"name": "/opt/ml/input/data/train", "duration": 65851, "num_epochs": 101, "num_examples": 9101}
# Billable seconds: 95

# %%
fm_predictor = fm.deploy(instance_type='ml.c4.xlarge', initial_instance_count=1)
# Out:
# INFO:sagemaker:Creating model with name: factorization-machines-2019-03-16-08-35-40-204
# INFO:sagemaker:Creating endpoint with name factorization-machines-2019-03-16-08-30-58-152
# ------------------------------------------------------------------!

# %%
def fm_serializer(data):
    js = {'instances': []}
    for row in data:
        js['instances'].append({'features': row.tolist()})
    #print js
    return json.dumps(js)

fm_predictor.content_type = 'application/json'
fm_predictor.serializer = fm_serializer
fm_predictor.deserializer = json_deserializer

# %%
resultSet = {
}
#for i in range(0,943*1682-200,200):
for i in range(0,943*1682-200,200):
    result = fm_predictor.predict(X_test[i:i+200].toarray())
    #print(result)


    with open('food1.test') as j, open('productDataJson.json') as productDataJson:
        pdJ = json.load(productDataJson)
        c=0
        for i,j in zip(result['predictions'],j.readlines()[i:i+200]):
            s = dict()
            k = j.split('\t')
            #s['uid'],s['pid'],s['isRecommended'],s['calorificValue'],s['cuisine'] = int(k[0]),int(k[1]),int(i['predicted_label']),pdJ[k[1]]["calorificValue"],pdJ[k[1]]["cuisine"]
            if int(k[0]) not in resultSet:
                resultSet[int(k[0])] = dict()
                #print("true")
            resultSet[int(k[0])][int(k[1])] = dict()
            resultSet[int(k[0])][int(k[1])]['isRecommended'],resultSet[int(k[0])][int(k[1])]['calorificValue'],resultSet[int(k[0])][int(k[1])]['cuisine'] = int(i['predicted_label']),pdJ[k[1]]["calorificValue"],pdJ[k[1]]["cuisine"]

            #resultSet['predictions'].append(s)
            """
            if(c==100):
                break
            c = c+1
            """
    #print(resultSet)
    f = open('predictions1.json','w+')
    f.write(json.dumps(resultSet))
    f.close()
